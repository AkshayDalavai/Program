# %%
# Import package
import tweepy
import json

# Store OAuth authentication credentials in relevant variables
access_token = "893472552936382468-huNxRsyYKfqT3LcuYBfAJktnDTap00b"
access_token_secret = "ZWvy1xMLZL4R43o7P0RkOJJk4LI02PMTW6t8CFiW6wDVV"
consumer_key = "LMDyYkChUODHEgA1qqHN43hD8"
consumer_secret = "RkxKvQ2nyOQqeCQe8yEYLfqXBUkQT8V2fzXWRPPbAed9bl9c2g"


# Pass OAuth details to tweepy's OAuth handler
auth = tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)

# %%
class MyStreamListener(tweepy.StreamListener):
    def __init__(self, api=None):
        super(MyStreamListener, self).__init__()
        self.num_tweets = 0
        self.file = open("tweets.txt", "w")

    def on_status(self, status):
        tweet = status._json
        self.file.write( json.dumps(tweet) + '\n' )
        self.num_tweets += 1
        if self.num_tweets < 100:
            return True
        else:
            return False
        self.file.close()

    def on_error(self, status):
        print(status)

# %%
# Initialize Stream listener
l = MyStreamListener()

# Create you Stream object with authentication
stream = tweepy.Stream(auth,l)


# Filter Twitter Streams to capture data by the keywords:
k=input("Enter the keyword: ").strip().split()
print(k)

stream.filter(track=k)
# Out:
# Enter the keyword: modi
# ['modi']

# %%
# String of path to file: tweets_data_path
tweets_data_path="tweets.txt"

# Initialize empty list to store tweets: tweets_data
tweets_data=[]

# Open connection to file
tweets_file = open(tweets_data_path, "r")
# Read in tweets and store in list: tweets_data
for line in tweets_file:
    tweet=json.loads(line)
    tweets_data.append(tweet)

# Close connection to file
tweets_file.close()

# Print the keys of the first tweet dict
print(tweets_data[0].keys())
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'source', 'truncated', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'retweeted_status', 'is_quote_status', 'quote_count', 'reply_count', 'retweet_count', 'favorite_count', 'entities', 'favorited', 'retweeted', 'filter_level', 'lang', 'timestamp_ms'])

# %%
di={}
l1=[y["user"]["name"] for y in tweets_data]
l2=[y["user"]["statuses_count"] for y in tweets_data]
l5=[y["created_at"] for y in tweets_data]
l3=[]

for y in tweets_data:
    
    a=(y["entities"]["urls"])
    
    if a==[]:
        l3.append(0)
    else:
        l3.append(a)
l4=[]        
for x in l3:
    if x==0:
        l4.append("link not used")
    else:
        l4.append(x[0]["expanded_url"])
        
        
       
di["NAMES"]=l1
di["COUNT OF TWEETS"]=l2
di["LINK REPORT"]=l4
di["CREATED_AT"]=l5

# Import package
import pandas as pd

# Build DataFrame of tweet texts and languages
df = pd.DataFrame(di)



# Print head of DataFrame
print(df.head(n=100))
# Out:
#     COUNT OF TWEETS                      CREATED_AT  \
# 0             45201  Fri Nov 24 08:12:19 +0000 2017
# 1             38263  Fri Nov 24 08:12:20 +0000 2017
# 2             35476  Fri Nov 24 08:12:20 +0000 2017
# 3             24258  Fri Nov 24 08:12:22 +0000 2017
# 4               305  Fri Nov 24 08:12:23 +0000 2017
# 5              9119  Fri Nov 24 08:12:24 +0000 2017
# 6             80663  Fri Nov 24 08:12:26 +0000 2017
# 7            107638  Fri Nov 24 08:12:28 +0000 2017
# 8             22394  Fri Nov 24 08:12:32 +0000 2017
# 9            104948  Fri Nov 24 08:12:33 +0000 2017
# 14                                      link not used
# 15                                      link not used
# 16                              http://ift.tt/2zjRMJs
# 17                                      link not used
# 18                                      link not used
# 19                                      link not used
# 20                                      link not used
# 21                                      link not used
# 22  http://gkojasjob.blogspot.com/2017/11/pm-modi-...
# 23  https://twitter.com/i/web/status/9339716216514...
# 24                                      link not used
# 25                                      link not used
# 26                                      link not used
# 27                                      link not used
# 28                              http://bit.ly/2iMqPrF
# 29                                      link not used
# ..                                                ...
# 69                      http://youtu.be/VDoMtjX2DYY?a
# 70                                      link not used
# 71  https://twitter.com/ShekharGupta/status/933933...
# 72                                      link not used
# 73                                      link not used
# 74                                      link not used
# 75                                      link not used
# 76                                      link not used
# 77                                      link not used
# 78  https://twitter.com/sagarikaghose/status/93396...
# 79                                      link not used
# 80  https://twitter.com/i/web/status/9339718456651...
# 81                                      link not used
# 82  https://twitter.com/IndiaToday/status/93397184...
# 83                                      link not used
# 84                               http://nm-4.com/x2p5
# 85                                      link not used
# 86                                      link not used
# 87  https://twitter.com/upbhaskar/status/933639651...
# 88                                      link not used
# 89  https://twitter.com/i/web/status/9339718723995...
# 90  https://twitter.com/i/web/status/9339718753188...
# 91                                      link not used
# 92                                      link not used
# 93                                      link not used
# 94                      http://youtu.be/MQcEUt1shfI?a
# 95  https://twitter.com/i/web/status/9339718859178...
# 96                                      link not used
# 97                                      link not used
# 98                                      link not used
#
#                                              NAMES
# 0                                       jigar varu
# 1                                              Lou
# 2                              Modi jee ka Patidar
# 3                             Chepuri Praveenkumar
# 4                                          Beatles
# 5                                           Apollo
# 6                                        SriSpeaks
# 7                                           Amit A
# 8                                      AMIT RANJAN
# 9                                          Tanweer
# 10                                         subhash
# 11                                     Prudhvi Raj
# 12                              #DestroyTheAadhaar
# 13  श्री कबूतरुद्दीन प्रसाद फर्नाडीस टुंडला वाले🐦🚩
# 14                                     anjali sing
# 15                                    Govinda Bhat
# 16                                   Vishal Shah ®
# 17                                           Merin
# 18                                       CommonMan
# 19                                      Netra Daoo
# 20                                  Sachin Krishna
# 21                                        Keerthi🌹
# 22                                     BESTPCGAMES
# 23                                      Kapil Kale
# 24                                   🚩विंध्यवासी 🚩
# 25                                  Srish Kulkarni
# 26                                           ₹€€म💖
# 27                                     S Venkatesh
# 28                                pradeep sarawagi
# 29                                    Girish Joshi
# ..                                             ...
# 69                                      Mahaa News
# 70                                              BP
# 71                                           Shubh
# 72                                        DarkYogi
# 73                                 Ashley Benjamin
# 74                                          siddhi
# 75                                     Rahul Patil
# 76                                     BINOD KUMAR
# 77                            Harsha Roy #ChaiWala
# 78                                    Sanjay Nayak
# 79                                           siraj
# 80                                     India Today
# 81                                      Vishnu Sen
# 82                                            Mitr
# 83                                     vimal kumar
# 84                            Yaduveer Singh baghe
# 85                                     Veteran_SKS
# 86                                   nagaraj hegde
# 87                                Ankit Srivastava
# 88                               Karthik Bharadwaj
# 89                                 Atul B. Kamothi
# 90                             Modi jee ka Patidar
# 91                                   Devil/Dervish
# 92                                Ramesh Ash kumar
# 93                                🇮🇳Jagdish Singh🚩
# 94                                     Anoop Verma
# 95                                   Mandar Sawant
# 96                       vijay सिर्फ  हिन्दू 🇮🇳 अँ
# 97                                    Masilamani.R
# 98                                          PINTOO
#
# [99 rows x 4 columns]
