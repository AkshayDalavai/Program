# %%
# Import package
import tweepy
import json
import time

# Store OAuth authentication credentials in relevant variables
access_token = "893472552936382468-huNxRsyYKfqT3LcuYBfAJktnDTap00b"
access_token_secret = "ZWvy1xMLZL4R43o7P0RkOJJk4LI02PMTW6t8CFiW6wDVV"
consumer_key = "LMDyYkChUODHEgA1qqHN43hD8"
consumer_secret = "RkxKvQ2nyOQqeCQe8yEYLfqXBUkQT8V2fzXWRPPbAed9bl9c2g"


# Pass OAuth details to tweepy's OAuth handler
auth = tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)

class MyStreamListener(tweepy.StreamListener):
    def __init__(self,time_limit=300, api=None):
        
        self.start_time = time.time()
        self.limit = time_limit
        self.file = open("tweets.txt", "w")
        super(MyStreamListener, self).__init__()

    def on_status(self, status):
        if (time.time()-self.start_time)<self.limit:
            tweet = status._json
            self.file.write( json.dumps(tweet) + '\n' )
            return True
        else:
            self.file.close()
            return False
        
    def on_error(self, status):
        print(status)

# Initialize Stream listener
l = MyStreamListener()

# Create you Stream object with authentication
stream = tweepy.Stream(auth,l)


# Filter Twitter Streams to capture data by the keywords:
k=input("Enter the keyword: ").strip().split()
print("Please wait for few min for the output")
stream.filter(track=k)


# String of path to file: tweets_data_path
tweets_data_path="tweets.txt"

# Initialize empty list to store tweets: tweets_data
tweets_data=[]

# Open connection to file
tweets_file = open(tweets_data_path, "r")
# Read in tweets and store in list: tweets_data
for line in tweets_file:
    tweet=json.loads(line)
    tweets_data.append(tweet)

# Close connection to file
tweets_file.close()

# Print the keys of the first tweet dict
#print(tweets_data[0].keys())
#print(tweets_data[0]["entities"])
di={}
l1=[y["user"]["name"] for y in tweets_data]
l2=[y["user"]["statuses_count"] for y in tweets_data]
l3=[]
l5=[y["created_at"] for y in tweets_data]
for y in tweets_data:
    
    a=(y["entities"]["urls"])
    
    if a==[]:
        l3.append(0)
    else:
        l3.append(a)
l4=[]        
for x in l3:
    if x==0:
        l4.append("link not used")
    else:
        l4.append(x[0]["expanded_url"])
        
        
di["cr"]=l5
di["NAMES"]=l1
di["COUNT OF TWEETS"]=l2
di["LINK REPORT"]=l4




# Import package
import pandas as pd

# Build DataFrame of tweet texts and languages
df = pd.DataFrame(di)


# Print head of DataFrame
print(df)
# Out:
# Enter the keyword: modi
# Please wait for few min for the output
#      COUNT OF TWEETS                                        LINK REPORT  \
# 0              71221  https://aajtak.intoday.in/story/manmohan-singh...
# 1              36047  http://indianexpress.com/article/india/karnata...
# 2              80491  https://twitter.com/anubhutivishnoi/status/940...
# 3               2381  http://www.hindi.indiasamvad.co.in/specialstor...
# 4              61141                                      link not used
# 5                588                                      link not used
# 6                 85  https://timesofindia.indiatimes.com/elections/...
# 7               1918  https://twitter.com/i/web/status/9409330115996...
# 8                 86                                      link not used
# 9             182679  https://twitter.com/chirag/status/940922513827...
# 10              5836                                      link not used
# 11             69259                                      link not used
# 12               129  https://twitter.com/i/web/status/9409330191411...
# 13            134002                           https://goo.gl/fb/4yyfKu
# 14            239367                                      link not used
# 15              5027                                      link not used
# 16               213                                      link not used
# 17             15801  http://www.timesnownews.com/amp/india/article/...
# 18              1848                                      link not used
# 19              7366                                      link not used
# 20             13514                                      link not used
# 21               832                                      link not used
# 22               118                                      link not used
# 23               890                                      link not used
# 24              5951                                      link not used
# 25              5926                                      link not used
# 26             42013  https://thewire.in/204448/mani-shankar-aiyar-l...
# 27               831                                      link not used
# 28             27073  https://twitter.com/i/web/status/9409330575607...
# 29             51688  https://twitter.com/i/web/status/9409330594188...
# ..               ...                                                ...
# 742            16568                                      link not used
# 743             1005                                      link not used
# 744               34  http://www.ndtv.com/india-news/hours-after-gre...
# 745           346495                             http://ecoti.in/W_XGhb
# 746             1132                                      link not used
# 747              462  http://abpnews.abplive.in/india-news/shatrugha...
# 748             5805  http://abpnews.abplive.in/india-news/shatrugha...
# 749            63734                                      link not used
# 750            19398                                      link not used
# 751            27969                                      link not used
# 752              981                                      link not used
# 753            21379  http://www.ndtv.com/india-news/hours-after-gre...
# 754              547                                      link not used
# 755             4500  https://twitter.com/i/web/status/9409341364028...
# 756                1  https://twitter.com/i/web/status/9409341376653...
# 757             3152                                      link not used
# 758            16569                                      link not used
# 759            20582  http://www.ndtv.com/india-news/hours-after-gre...
# 760              922                                      link not used
# 761               10                                      link not used
# 762             9131                                      link not used
# 763            12848                                      link not used
# 764             6995                                      link not used
# 765            13334                                      link not used
# 766           173869                                      link not used
# 767            95925  https://twitter.com/BTVI/status/94090492014782...
# 768              547  https://twitter.com/ARanganathan72/status/9409...
# 769             5892                                      link not used
# 770             1827                                      link not used
# 771             1061                                      link not used
#
#                                               NAMES  \
# 0                                                PB
# 1                                            swaraj
# 2                                       Vinod gupta
# 3                                             Javed
# 4                                   AKtivist Abbidi
# 5                                          ROFL_EVM
# 6                               Manishbhai Barejiya
# 7           ⚘Ek  hindu ⚘Garv se kaho hum hindu he ⚘
# 8                               Manishbhai Barejiya
# 9    #IamNotCoolAnymore #WhyDoYouLoveMe #BoostMyEgo
# 10                              GULAB CHANDRA YADAV
# 11                                      Ankit Yadav
# 12                                 vincenzo lubrano
# 13                                         NRIPress
# 14                                   Biswajeet Dash
# 15                                      Rahul Meena
# 16                              ThePeopleOfVadodara
# 17                                            مہرین
# 18                                    Shubham Singh
# 19                                  Shubham Awasthi
# 20                                       Yash Raval
# 21                                     lakhan varma
# 22                                KHUSHIRAM DOI IYC
# 23                                     Girija Pande
# 24                                          shobhit
# 25                                     JAGDEEP RANA
# 26                                   Curious Indian
# 27                                      Rahul verma
# 28                                The Best of Media
# 29                                 Swati Chaturvedi
# ..                                              ...
# 742                                Sujay Chaturvedi
# 743                                   Santosh Bajad
# 744                                Agarwal Jagdamba
# 745                               SAMARJEET NARAYAN
# 746                             Vijay Trivedi B.J.P
# 747                                   Muazzam Mirza
# 748                                  NISHATUL  AZAM
# 749                                         chandra
# 750                                      S L Sriram
# 751                                         N Anjum
# 752                             Subhankhi Paramguru
# 753                                          Gaurav
# 754                                 Pradeep Subudhi
# 755                                 CA Manish Lukka
# 756                                    Rupen Gurjar
# 757                                    Mukesh Kumar
# 758                                Sujay Chaturvedi
# 759                                          Dileep
# 760                                   SIVA PRASAD G
# 761                                 Mohsin Ali Khan
# 762                                  Manna Kushwaha
# 763                                     Sohan Tomar
# 764                                   Merphy Philip
# 765                                   Husain Akhtar
# 766                                    rajat sharma
# 767                                    Kushan Mitra
# 768                              K.N. PALACHANDRAN.
# 769                               Sumeysh Manchanda
# 770                                           sofia
# 771                                  Prakash Sharma
#
#                                  cr
# 0    Wed Dec 13 13:14:42 +0000 2017
# 1    Wed Dec 13 13:14:43 +0000 2017
# 2    Wed Dec 13 13:14:43 +0000 2017
# 3    Wed Dec 13 13:14:44 +0000 2017
# 4    Wed Dec 13 13:14:44 +0000 2017
# 5    Wed Dec 13 13:14:44 +0000 2017
# 6    Wed Dec 13 13:14:45 +0000 2017
# 7    Wed Dec 13 13:14:46 +0000 2017
# 8    Wed Dec 13 13:14:47 +0000 2017
# 9    Wed Dec 13 13:14:48 +0000 2017
# 10   Wed Dec 13 13:14:48 +0000 2017
# 11   Wed Dec 13 13:14:48 +0000 2017
# 12   Wed Dec 13 13:14:48 +0000 2017
# 13   Wed Dec 13 13:14:48 +0000 2017
# 14   Wed Dec 13 13:14:50 +0000 2017
# 15   Wed Dec 13 13:14:51 +0000 2017
# 16   Wed Dec 13 13:14:51 +0000 2017
# 17   Wed Dec 13 13:14:52 +0000 2017
# 18   Wed Dec 13 13:14:52 +0000 2017
# 19   Wed Dec 13 13:14:53 +0000 2017
# 20   Wed Dec 13 13:14:54 +0000 2017
# 21   Wed Dec 13 13:14:54 +0000 2017
# 22   Wed Dec 13 13:14:55 +0000 2017
# 23   Wed Dec 13 13:14:55 +0000 2017
# 24   Wed Dec 13 13:14:55 +0000 2017
# 25   Wed Dec 13 13:14:55 +0000 2017
# 26   Wed Dec 13 13:14:56 +0000 2017
# 27   Wed Dec 13 13:14:57 +0000 2017
# 28   Wed Dec 13 13:14:57 +0000 2017
# 29   Wed Dec 13 13:14:57 +0000 2017
# ..                              ...
# 742  Wed Dec 13 13:19:10 +0000 2017
# 743  Wed Dec 13 13:19:10 +0000 2017
# 744  Wed Dec 13 13:19:10 +0000 2017
# 745  Wed Dec 13 13:19:10 +0000 2017
# 746  Wed Dec 13 13:19:11 +0000 2017
# 747  Wed Dec 13 13:19:11 +0000 2017
# 748  Wed Dec 13 13:19:11 +0000 2017
# 749  Wed Dec 13 13:19:12 +0000 2017
# 750  Wed Dec 13 13:19:12 +0000 2017
# 751  Wed Dec 13 13:19:12 +0000 2017
# 752  Wed Dec 13 13:19:12 +0000 2017
# 753  Wed Dec 13 13:19:13 +0000 2017
# 754  Wed Dec 13 13:19:14 +0000 2017
# 755  Wed Dec 13 13:19:14 +0000 2017
# 756  Wed Dec 13 13:19:14 +0000 2017
# 757  Wed Dec 13 13:19:15 +0000 2017
# 758  Wed Dec 13 13:19:15 +0000 2017
# 759  Wed Dec 13 13:19:15 +0000 2017
# 760  Wed Dec 13 13:19:15 +0000 2017
# 761  Wed Dec 13 13:19:16 +0000 2017
# 762  Wed Dec 13 13:19:17 +0000 2017
# 763  Wed Dec 13 13:19:18 +0000 2017
# 764  Wed Dec 13 13:19:18 +0000 2017
# 765  Wed Dec 13 13:19:18 +0000 2017
# 766  Wed Dec 13 13:19:19 +0000 2017
# 767  Wed Dec 13 13:19:20 +0000 2017
# 768  Wed Dec 13 13:19:20 +0000 2017
# 769  Wed Dec 13 13:19:21 +0000 2017
# 770  Wed Dec 13 13:19:21 +0000 2017
# 771  Wed Dec 13 13:19:21 +0000 2017
#
# [772 rows x 4 columns]
